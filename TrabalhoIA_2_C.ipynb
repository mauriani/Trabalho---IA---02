# %%
# !pip install pandas scikit-learn tensorflow
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# %%
url = "https://raw.githubusercontent.com/incribo-inc/cybersecurity_attacks/main/cybersecurity_attacks.csv"
df = pd.read_csv(url)
print(df)
# Out:
#                  Timestamp Source IP Address Destination IP Address  \
# 0      2023-05-30 06:33:58     103.216.15.12           84.9.164.252
# 1      2020-08-26 07:08:30    78.199.217.198         66.191.137.154
# 2      2022-11-13 08:23:25      63.79.210.48          198.219.82.17
# 3      2023-07-02 10:38:46     163.42.196.10        101.228.192.255
# 4      2023-07-16 13:11:07     71.166.185.76        189.243.174.238
# ...                    ...               ...                    ...
# 39995  2023-05-26 14:08:42      26.36.109.26         121.100.75.240
# 39996  2023-03-27 00:38:27      17.21.163.81         196.108.134.78
# 39997  2022-03-31 01:45:49     162.35.217.57            98.107.0.15
# 39998  2023-09-22 18:32:38    208.72.233.205         173.79.112.252
# 39999  2023-10-10 11:59:52     14.102.21.108           109.198.45.7
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 0            31225             17616     ICMP            503        Data
# 1            17245             48166     ICMP           1174        Data
# 2            16811             53600      UDP            306     Control
# 3            20018             32534      UDP            385        Data
# 4             6131             26646      TCP           1462        Data
# ...            ...               ...      ...            ...         ...
# 39995        31005              6764      UDP           1428     Control
# 39996         2553             28091      UDP           1184     Control
# 39997        22505             25152      UDP           1043        Data
# 39998        20013              2703      UDP            483        Data
# 39999        50137             55575     ICMP           1175     Control
#
#       Traffic Type                                       Payload Data  ...  \
# 0             HTTP  Qui natus odio asperiores nam. Optio nobis ius...  ...
# 1             HTTP  Aperiam quos modi officiis veritatis rem. Omni...  ...
# 2             HTTP  Perferendis sapiente vitae soluta. Hic delectu...  ...
# 3             HTTP  Totam maxime beatae expedita explicabo porro l...  ...
# 4              DNS  Odit nesciunt dolorem nisi iste iusto. Animi v...  ...
# ...            ...                                                ...  ...
# 39995         HTTP  Quibusdam ullam consequatur consequuntur accus...  ...
# 39996         HTTP  Quaerat neque esse. Animi expedita natus commo...  ...
# 39997          DNS  Enim at aspernatur illum. Saepe numquam eligen...  ...
# 39998          FTP  Officiis dolorem sed harum provident earum dis...  ...
# 39999         HTTP  Eligendi omnis voluptate nihil voluptatibus do...  ...
#
#       Action Taken  Severity Level User Information  \
# 0           Logged             Low    Reyansh Dugal
# 1          Blocked             Low       Sumer Rana
# 2          Ignored             Low     Himmat Karpe
# 3          Blocked          Medium       Fateh Kibe
# 4          Blocked             Low     Dhanush Chad
# ...            ...             ...              ...
# 39995       Logged          Medium      Adira Madan
# 39996       Logged            High        Rati Dara
# 39997      Blocked             Low     Samiha Joshi
# 39998      Ignored             Low    Rasha Chauhan
# 39999       Logged          Medium      Zaina Kumar
#
#                                       Device Information Network Segment  \
# 0      Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...       Segment A
# 1      Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...       Segment B
# 2      Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...       Segment C
# 3      Mozilla/5.0 (Macintosh; PPC Mac OS X 10_11_5; ...       Segment B
# 4      Mozilla/5.0 (compatible; MSIE 5.0; Windows NT ...       Segment C
# ...                                                  ...             ...
# 39995  Mozilla/5.0 (iPad; CPU iPad OS 14_2_1 like Mac...       Segment A
# 39996  Mozilla/5.0 (Windows; U; Windows 98; Win 9x 4....       Segment C
# 39997  Mozilla/5.0 (Windows; U; Windows NT 4.0) Apple...       Segment C
# 39998  Mozilla/5.0 (X11; Linux i686) AppleWebKit/536....       Segment B
# 39999  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_0 like M...       Segment A
#
#                    Geo-location Data Proxy Information Firewall Logs  \
# 0                 Jamshedpur, Sikkim      150.9.97.135      Log Data
# 1                 Bilaspur, Nagaland               NaN      Log Data
# 2                  Bokaro, Rajasthan    114.133.48.179      Log Data
# 3                 Jaunpur, Rajasthan               NaN           NaN
# 4                 Anantapur, Tripura     149.6.110.119           NaN
# ...                              ...               ...           ...
# 39995                Nashik, Manipur               NaN      Log Data
# 39996              Vadodara, Mizoram       60.51.30.46      Log Data
# 39997  Mahbubnagar, Himachal Pradesh               NaN      Log Data
# 39998    Rourkela, Arunachal Pradesh      137.76.130.8      Log Data
# 39999       Pudukkottai, West Bengal   112.169.115.139      Log Data
#
#       IDS/IPS Alerts Log Source
# 0                NaN     Server
# 1                NaN   Firewall
# 2         Alert Data   Firewall
# 3         Alert Data   Firewall
# 4         Alert Data   Firewall
# ...              ...        ...
# 39995     Alert Data   Firewall
# 39996            NaN   Firewall
# 39997     Alert Data     Server
# 39998            NaN     Server
# 39999     Alert Data   Firewall
#
# [40000 rows x 25 columns]

# %%
# Identificar colunas numéricas e preechendo valores faltantes
numeric_columns = df.select_dtypes(include=[np.number]).columns

df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].median())

# Setando como Unknown colunas categóricas
categorical_columns = df.select_dtypes(include=['object']).columns
df[categorical_columns] = df[categorical_columns].fillna("Unknown")

print(df.head())

X = df.drop(columns=["Severity Level"])
y = df["Severity Level"]
# Out:
#              Timestamp Source IP Address Destination IP Address  Source Port  \
# 0  2023-05-30 06:33:58     103.216.15.12           84.9.164.252        31225
# 1  2020-08-26 07:08:30    78.199.217.198         66.191.137.154        17245
# 2  2022-11-13 08:23:25      63.79.210.48          198.219.82.17        16811
# 3  2023-07-02 10:38:46     163.42.196.10        101.228.192.255        20018
# 4  2023-07-16 13:11:07     71.166.185.76        189.243.174.238         6131
#
#    Destination Port Protocol  Packet Length Packet Type Traffic Type  \
# 0             17616     ICMP            503        Data         HTTP
# 1             48166     ICMP           1174        Data         HTTP
# 2             53600      UDP            306     Control         HTTP
# 3             32534      UDP            385        Data         HTTP
# 4             26646      TCP           1462        Data          DNS
#
#                                         Payload Data  ... Action Taken  \
# 0  Qui natus odio asperiores nam. Optio nobis ius...  ...       Logged
# 1  Aperiam quos modi officiis veritatis rem. Omni...  ...      Blocked
# 2  Perferendis sapiente vitae soluta. Hic delectu...  ...      Ignored
# 3  Totam maxime beatae expedita explicabo porro l...  ...      Blocked
# 4  Odit nesciunt dolorem nisi iste iusto. Animi v...  ...      Blocked
#
#    Severity Level User Information  \
# 0             Low    Reyansh Dugal
# 1             Low       Sumer Rana
# 2             Low     Himmat Karpe
# 3          Medium       Fateh Kibe
# 4             Low     Dhanush Chad
#
#                                   Device Information Network Segment  \
# 0  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...       Segment A
# 1  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...       Segment B
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...       Segment C
# 3  Mozilla/5.0 (Macintosh; PPC Mac OS X 10_11_5; ...       Segment B
# 4  Mozilla/5.0 (compatible; MSIE 5.0; Windows NT ...       Segment C
#
#     Geo-location Data Proxy Information Firewall Logs IDS/IPS Alerts  \
# 0  Jamshedpur, Sikkim      150.9.97.135      Log Data        Unknown
# 1  Bilaspur, Nagaland           Unknown      Log Data        Unknown
# 2   Bokaro, Rajasthan    114.133.48.179      Log Data     Alert Data
# 3  Jaunpur, Rajasthan           Unknown       Unknown     Alert Data
# 4  Anantapur, Tripura     149.6.110.119       Unknown     Alert Data
#
#   Log Source
# 0     Server
# 1   Firewall
# 2   Firewall
# 3   Firewall
# 4   Firewall
#
# [5 rows x 25 columns]

# %%
numeric_columns = X.select_dtypes(include=[np.number]).columns
X_numeric = X[numeric_columns]

# Normalização das variáveis numéricas
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_numeric)

# Transformação da variável alvo em categorias
if y.dtype != np.number:
    y = y.astype("category").cat.codes
y_categorical = to_categorical(y)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_categorical, test_size=0.3, random_state=42)
# Out:
# <ipython-input-13-4e273ce9bd19>:9: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if y.dtype != np.number:

# %%
# Função para construir e compilar o modelo
def build_model(layers, neurons, dropout_rate):
    model = Sequential()
    model.add(Dense(neurons[0], activation='relu', input_shape=(X_train.shape[1],)))
    model.add(Dropout(dropout_rate[0]))

    for layer, neuron, dropout in zip(range(layers - 1), neurons[1:], dropout_rate[1:]):
        model.add(Dense(neuron, activation='relu'))
        model.add(Dropout(dropout))

    model.add(Dense(y_train.shape[1], activation='softmax'))
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Treinamento e avaliação com diferentes topologias
topologies = [
    {"layers": 1, "neurons": [64], "dropout_rate": [0.2]},
    {"layers": 2, "neurons": [64, 32], "dropout_rate": [0.2, 0.3]},
    {"layers": 3, "neurons": [128, 64, 32], "dropout_rate": [0.3, 0.3, 0.4]}
]

# %%
results = []
for idx, topology in enumerate(topologies, 1):
    print(f"Treinando modelo {idx} com topologia: {topology}")
    model = build_model(**topology)
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test),
                        epochs=50, batch_size=32, verbose=1)
    # Avaliar o modelo
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
    results.append({"Model": f"Modelo {idx}", "Accuracy": test_acc, "Loss": test_loss})
    print(f"Modelo {idx} - Acurácia: {test_acc:.4f} - Loss: {test_loss:.4f}")
# Out:
# Treinando modelo 1 com topologia: {'layers': 1, 'neurons': [64], 'dropout_rate': [0.2]}
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3312 - loss: 1.1102 - val_accuracy: 0.3314 - val_loss: 1.1017
# Epoch 2/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3352 - loss: 1.1024 - val_accuracy: 0.3271 - val_loss: 1.1010
# Epoch 3/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3365 - loss: 1.1011 - val_accuracy: 0.3348 - val_loss: 1.0993
# Epoch 4/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3395 - loss: 1.0996 - val_accuracy: 0.3372 - val_loss: 1.0992
# Epoch 5/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3378 - loss: 1.0995 - val_accuracy: 0.3261 - val_loss: 1.1000
# Epoch 6/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.3358 - loss: 1.0988 - val_accuracy: 0.3278 - val_loss: 1.0997
# Epoch 7/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3453 - loss: 1.0983 - val_accuracy: 0.3266 - val_loss: 1.0999
# Epoch 8/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3450 - loss: 1.0985 - val_accuracy: 0.3287 - val_loss: 1.0994
# Epoch 9/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3394 - loss: 1.0986 - val_accuracy: 0.3247 - val_loss: 1.0997
# Epoch 10/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3438 - loss: 1.0982 - val_accuracy: 0.3307 - val_loss: 1.0995
# Epoch 11/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3371 - loss: 1.0986 - val_accuracy: 0.3243 - val_loss: 1.1001
# Epoch 12/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3411 - loss: 1.0985 - val_accuracy: 0.3234 - val_loss: 1.0997
# Epoch 13/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3425 - loss: 1.0983 - val_accuracy: 0.3322 - val_loss: 1.0991
# Epoch 14/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3402 - loss: 1.0983 - val_accuracy: 0.3341 - val_loss: 1.0997
# Epoch 15/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3436 - loss: 1.0983 - val_accuracy: 0.3284 - val_loss: 1.0997
# Epoch 16/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3431 - loss: 1.0986 - val_accuracy: 0.3243 - val_loss: 1.0999
# Epoch 17/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3487 - loss: 1.0981 - val_accuracy: 0.3329 - val_loss: 1.0994
# Epoch 18/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3461 - loss: 1.0980 - val_accuracy: 0.3338 - val_loss: 1.0995
# Epoch 19/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3503 - loss: 1.0978 - val_accuracy: 0.3297 - val_loss: 1.0993
# Epoch 20/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3484 - loss: 1.0978 - val_accuracy: 0.3284 - val_loss: 1.0998
# Epoch 21/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3450 - loss: 1.0984 - val_accuracy: 0.3307 - val_loss: 1.1001
# Epoch 22/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3446 - loss: 1.0980 - val_accuracy: 0.3216 - val_loss: 1.0997
# Epoch 23/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3458 - loss: 1.0978 - val_accuracy: 0.3338 - val_loss: 1.0997
# Epoch 24/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3468 - loss: 1.0983 - val_accuracy: 0.3364 - val_loss: 1.0993
# Epoch 25/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3461 - loss: 1.0982 - val_accuracy: 0.3337 - val_loss: 1.0996
# Epoch 26/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3432 - loss: 1.0979 - val_accuracy: 0.3277 - val_loss: 1.0994
# Epoch 27/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3402 - loss: 1.0979 - val_accuracy: 0.3339 - val_loss: 1.0993
# Epoch 28/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3439 - loss: 1.0979 - val_accuracy: 0.3249 - val_loss: 1.0998
# Epoch 29/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.3478 - loss: 1.0978 - val_accuracy: 0.3257 - val_loss: 1.0998
# Epoch 30/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3465 - loss: 1.0973 - val_accuracy: 0.3238 - val_loss: 1.0999
# Epoch 31/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3441 - loss: 1.0980 - val_accuracy: 0.3277 - val_loss: 1.0998
# Epoch 32/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3422 - loss: 1.0983 - val_accuracy: 0.3257 - val_loss: 1.0998
# Epoch 33/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3482 - loss: 1.0977 - val_accuracy: 0.3304 - val_loss: 1.0997
# Epoch 34/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3429 - loss: 1.0978 - val_accuracy: 0.3257 - val_loss: 1.1001
# Epoch 35/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3469 - loss: 1.0977 - val_accuracy: 0.3311 - val_loss: 1.0996
# Epoch 36/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3505 - loss: 1.0978 - val_accuracy: 0.3340 - val_loss: 1.0998
# Epoch 37/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3471 - loss: 1.0976 - val_accuracy: 0.3314 - val_loss: 1.1002
# Epoch 38/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3456 - loss: 1.0981 - val_accuracy: 0.3317 - val_loss: 1.1001
# Epoch 39/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3527 - loss: 1.0974 - val_accuracy: 0.3286 - val_loss: 1.0997
# Epoch 40/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3529 - loss: 1.0977 - val_accuracy: 0.3243 - val_loss: 1.0999
# Epoch 41/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3482 - loss: 1.0978 - val_accuracy: 0.3360 - val_loss: 1.0997
# Epoch 42/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3483 - loss: 1.0978 - val_accuracy: 0.3282 - val_loss: 1.0997
# Epoch 43/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3476 - loss: 1.0976 - val_accuracy: 0.3332 - val_loss: 1.1000
# Epoch 44/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3376 - loss: 1.0979 - val_accuracy: 0.3322 - val_loss: 1.1004
# Epoch 45/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3509 - loss: 1.0973 - val_accuracy: 0.3325 - val_loss: 1.0997
# Epoch 46/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3511 - loss: 1.0973 - val_accuracy: 0.3295 - val_loss: 1.0995
# Epoch 47/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3493 - loss: 1.0973 - val_accuracy: 0.3291 - val_loss: 1.0996
# Epoch 48/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3469 - loss: 1.0969 - val_accuracy: 0.3211 - val_loss: 1.0998
# Epoch 49/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3458 - loss: 1.0974 - val_accuracy: 0.3318 - val_loss: 1.1003
# Epoch 50/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3436 - loss: 1.0980 - val_accuracy: 0.3291 - val_loss: 1.1000
# Modelo 1 - Acurácia: 0.3291 - Loss: 1.1000
# Treinando modelo 2 com topologia: {'layers': 2, 'neurons': [64, 32], 'dropout_rate': [0.2, 0.3]}
# Epoch 1/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3278 - loss: 1.1121 - val_accuracy: 0.3317 - val_loss: 1.0992
# Epoch 2/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3334 - loss: 1.0992 - val_accuracy: 0.3259 - val_loss: 1.0994
# Epoch 3/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3442 - loss: 1.0986 - val_accuracy: 0.3359 - val_loss: 1.0990
# Epoch 4/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3402 - loss: 1.0984 - val_accuracy: 0.3369 - val_loss: 1.0988
# Epoch 5/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3368 - loss: 1.0987 - val_accuracy: 0.3392 - val_loss: 1.0989
# Epoch 6/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3316 - loss: 1.0988 - val_accuracy: 0.3248 - val_loss: 1.0990
# Epoch 7/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3403 - loss: 1.0984 - val_accuracy: 0.3284 - val_loss: 1.0992
# Epoch 8/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3417 - loss: 1.0983 - val_accuracy: 0.3223 - val_loss: 1.0991
# Epoch 9/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3405 - loss: 1.0987 - val_accuracy: 0.3292 - val_loss: 1.0992
# Epoch 10/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3431 - loss: 1.0983 - val_accuracy: 0.3286 - val_loss: 1.0992
# Epoch 11/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3341 - loss: 1.0987 - val_accuracy: 0.3244 - val_loss: 1.0991
# Epoch 12/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.3341 - loss: 1.0984 - val_accuracy: 0.3281 - val_loss: 1.0995
# Epoch 13/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3432 - loss: 1.0983 - val_accuracy: 0.3344 - val_loss: 1.0992
# Epoch 14/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3334 - loss: 1.0988 - val_accuracy: 0.3331 - val_loss: 1.0989
# Epoch 15/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3371 - loss: 1.0984 - val_accuracy: 0.3358 - val_loss: 1.0991
# Epoch 16/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3401 - loss: 1.0985 - val_accuracy: 0.3266 - val_loss: 1.0992
# Epoch 17/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.3326 - loss: 1.0986 - val_accuracy: 0.3312 - val_loss: 1.0992
# Epoch 18/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3367 - loss: 1.0986 - val_accuracy: 0.3305 - val_loss: 1.0993
# Epoch 19/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3410 - loss: 1.0979 - val_accuracy: 0.3331 - val_loss: 1.0989
# Epoch 20/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3373 - loss: 1.0983 - val_accuracy: 0.3311 - val_loss: 1.0995
# Epoch 21/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3381 - loss: 1.0984 - val_accuracy: 0.3242 - val_loss: 1.0991
# Epoch 22/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3405 - loss: 1.0982 - val_accuracy: 0.3243 - val_loss: 1.0995
# Epoch 23/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3408 - loss: 1.0987 - val_accuracy: 0.3242 - val_loss: 1.0998
# Epoch 24/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3420 - loss: 1.0985 - val_accuracy: 0.3266 - val_loss: 1.0998
# Epoch 25/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3372 - loss: 1.0984 - val_accuracy: 0.3233 - val_loss: 1.0995
# Epoch 26/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3418 - loss: 1.0981 - val_accuracy: 0.3248 - val_loss: 1.0996
# Epoch 27/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3419 - loss: 1.0978 - val_accuracy: 0.3285 - val_loss: 1.0994
# Epoch 28/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3372 - loss: 1.0983 - val_accuracy: 0.3264 - val_loss: 1.0993
# Epoch 29/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3423 - loss: 1.0977 - val_accuracy: 0.3310 - val_loss: 1.0992
# Epoch 30/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3442 - loss: 1.0980 - val_accuracy: 0.3192 - val_loss: 1.0996
# Epoch 31/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3461 - loss: 1.0977 - val_accuracy: 0.3305 - val_loss: 1.0995
# Epoch 32/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3409 - loss: 1.0979 - val_accuracy: 0.3249 - val_loss: 1.0994
# Epoch 33/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3411 - loss: 1.0981 - val_accuracy: 0.3323 - val_loss: 1.0999
# Epoch 34/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3420 - loss: 1.0981 - val_accuracy: 0.3293 - val_loss: 1.0996
# Epoch 35/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3395 - loss: 1.0978 - val_accuracy: 0.3224 - val_loss: 1.0994
# Epoch 36/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3428 - loss: 1.0979 - val_accuracy: 0.3213 - val_loss: 1.0998
# Epoch 37/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3417 - loss: 1.0978 - val_accuracy: 0.3245 - val_loss: 1.0998
# Epoch 38/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3432 - loss: 1.0983 - val_accuracy: 0.3223 - val_loss: 1.0997
# Epoch 39/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3372 - loss: 1.0983 - val_accuracy: 0.3257 - val_loss: 1.1000
# Epoch 40/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3397 - loss: 1.0982 - val_accuracy: 0.3236 - val_loss: 1.1003
# Epoch 41/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3449 - loss: 1.0979 - val_accuracy: 0.3231 - val_loss: 1.0996
# Epoch 42/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3437 - loss: 1.0978 - val_accuracy: 0.3213 - val_loss: 1.1000
# Epoch 43/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3382 - loss: 1.0984 - val_accuracy: 0.3232 - val_loss: 1.0998
# Epoch 44/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3481 - loss: 1.0973 - val_accuracy: 0.3258 - val_loss: 1.0996
# Epoch 45/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3448 - loss: 1.0981 - val_accuracy: 0.3274 - val_loss: 1.0998
# Epoch 46/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3429 - loss: 1.0979 - val_accuracy: 0.3300 - val_loss: 1.0996
# Epoch 47/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3385 - loss: 1.0981 - val_accuracy: 0.3287 - val_loss: 1.0999
# Epoch 48/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3452 - loss: 1.0977 - val_accuracy: 0.3307 - val_loss: 1.0996
# Epoch 49/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3407 - loss: 1.0981 - val_accuracy: 0.3207 - val_loss: 1.0997
# Epoch 50/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3410 - loss: 1.0982 - val_accuracy: 0.3201 - val_loss: 1.1002
# Modelo 2 - Acurácia: 0.3201 - Loss: 1.1002
# Treinando modelo 3 com topologia: {'layers': 3, 'neurons': [128, 64, 32], 'dropout_rate': [0.3, 0.3, 0.4]}
# Epoch 1/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.3388 - loss: 1.1041 - val_accuracy: 0.3415 - val_loss: 1.0989
# Epoch 2/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3369 - loss: 1.0989 - val_accuracy: 0.3354 - val_loss: 1.0987
# Epoch 3/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3348 - loss: 1.0988 - val_accuracy: 0.3252 - val_loss: 1.0990
# Epoch 4/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3388 - loss: 1.0985 - val_accuracy: 0.3347 - val_loss: 1.0990
# Epoch 5/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3338 - loss: 1.0987 - val_accuracy: 0.3390 - val_loss: 1.0993
# Epoch 6/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3337 - loss: 1.0988 - val_accuracy: 0.3298 - val_loss: 1.0988
# Epoch 7/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3351 - loss: 1.0986 - val_accuracy: 0.3283 - val_loss: 1.0989
# Epoch 8/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3381 - loss: 1.0986 - val_accuracy: 0.3368 - val_loss: 1.0988
# Epoch 9/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3285 - loss: 1.0988 - val_accuracy: 0.3378 - val_loss: 1.0988
# Epoch 10/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3288 - loss: 1.0989 - val_accuracy: 0.3278 - val_loss: 1.0989
# Epoch 11/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3371 - loss: 1.0984 - val_accuracy: 0.3307 - val_loss: 1.0988
# Epoch 12/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3374 - loss: 1.0987 - val_accuracy: 0.3332 - val_loss: 1.0991
# Epoch 13/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3320 - loss: 1.0989 - val_accuracy: 0.3321 - val_loss: 1.0994
# Epoch 14/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3376 - loss: 1.0987 - val_accuracy: 0.3271 - val_loss: 1.0988
# Epoch 15/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3352 - loss: 1.0986 - val_accuracy: 0.3363 - val_loss: 1.0989
# Epoch 16/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3365 - loss: 1.0986 - val_accuracy: 0.3278 - val_loss: 1.0989
# Epoch 17/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3343 - loss: 1.0987 - val_accuracy: 0.3394 - val_loss: 1.0988
# Epoch 18/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3376 - loss: 1.0986 - val_accuracy: 0.3277 - val_loss: 1.0990
# Epoch 19/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3418 - loss: 1.0987 - val_accuracy: 0.3364 - val_loss: 1.0987
# Epoch 20/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3333 - loss: 1.0986 - val_accuracy: 0.3368 - val_loss: 1.0987
# Epoch 21/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3333 - loss: 1.0987 - val_accuracy: 0.3396 - val_loss: 1.0988
# Epoch 22/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3394 - loss: 1.0986 - val_accuracy: 0.3411 - val_loss: 1.0989
# Epoch 23/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3329 - loss: 1.0988 - val_accuracy: 0.3284 - val_loss: 1.0990
# Epoch 24/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3420 - loss: 1.0985 - val_accuracy: 0.3390 - val_loss: 1.0987
# Epoch 25/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3286 - loss: 1.0988 - val_accuracy: 0.3380 - val_loss: 1.0990
# Epoch 26/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3415 - loss: 1.0986 - val_accuracy: 0.3283 - val_loss: 1.0989
# Epoch 27/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3316 - loss: 1.0986 - val_accuracy: 0.3404 - val_loss: 1.0989
# Epoch 28/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3398 - loss: 1.0986 - val_accuracy: 0.3382 - val_loss: 1.0989
# Epoch 29/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3330 - loss: 1.0987 - val_accuracy: 0.3377 - val_loss: 1.0987
# Epoch 30/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3355 - loss: 1.0985 - val_accuracy: 0.3242 - val_loss: 1.0991
# Epoch 31/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3390 - loss: 1.0985 - val_accuracy: 0.3372 - val_loss: 1.0988
# Epoch 32/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3333 - loss: 1.0987 - val_accuracy: 0.3299 - val_loss: 1.0987
# Epoch 33/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3361 - loss: 1.0987 - val_accuracy: 0.3270 - val_loss: 1.0990
# Epoch 34/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3429 - loss: 1.0984 - val_accuracy: 0.3368 - val_loss: 1.0988
# Epoch 35/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.3364 - loss: 1.0985 - val_accuracy: 0.3342 - val_loss: 1.0988
# Epoch 36/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3374 - loss: 1.0984 - val_accuracy: 0.3372 - val_loss: 1.0990
# Epoch 37/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3339 - loss: 1.0988 - val_accuracy: 0.3262 - val_loss: 1.0990
# Epoch 38/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3401 - loss: 1.0985 - val_accuracy: 0.3377 - val_loss: 1.0988
# Epoch 39/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.3369 - loss: 1.0984 - val_accuracy: 0.3276 - val_loss: 1.0990
# Epoch 40/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3425 - loss: 1.0982 - val_accuracy: 0.3207 - val_loss: 1.0994
# Epoch 41/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3359 - loss: 1.0989 - val_accuracy: 0.3250 - val_loss: 1.0991
# Epoch 42/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3403 - loss: 1.0984 - val_accuracy: 0.3279 - val_loss: 1.0988
# Epoch 43/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3415 - loss: 1.0984 - val_accuracy: 0.3253 - val_loss: 1.0989
# Epoch 44/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3359 - loss: 1.0985 - val_accuracy: 0.3277 - val_loss: 1.0988
# Epoch 45/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.3399 - loss: 1.0984 - val_accuracy: 0.3291 - val_loss: 1.0987
# Epoch 46/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3303 - loss: 1.0986 - val_accuracy: 0.3368 - val_loss: 1.0989
# Epoch 47/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3405 - loss: 1.0985 - val_accuracy: 0.3272 - val_loss: 1.0990
# Epoch 48/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3350 - loss: 1.0985 - val_accuracy: 0.3368 - val_loss: 1.0987
# Epoch 49/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.3394 - loss: 1.0986 - val_accuracy: 0.3282 - val_loss: 1.0989
# Epoch 50/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3403 - loss: 1.0983 - val_accuracy: 0.3284 - val_loss: 1.0989
# Modelo 3 - Acurácia: 0.3284 - Loss: 1.0989

# %%
results_df = pd.DataFrame(results)
print("\nResultados comparativos:")
print(results_df)
# Out:
# Resultados comparativos:
#       Model  Accuracy      Loss
# 0  Modelo 1  0.329083  1.100001
# 1  Modelo 2  0.320083  1.100175
# 2  Modelo 3  0.328417  1.098920
